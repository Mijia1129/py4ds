# %%
import pandas as pd

# %%
# import API csv file and slip the first 4 rows since there is a title in the first 4 rows.

# %%
API = pd.read_csv('/Users/mijia/Desktop/Spring 2020/BANA 8090/API_NY/API_NY.GDP.csv', skiprows=4)

# %%
# check number of columns and rows in API DataFrame.

# %%
API.shape
# Out:
# (264, 65)

# %%
# glimpse view of API DataFrame.

# %%
API.head()
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965  ...      2011       2012      2013      2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  3.446055  -1.369863  4.198232  0.848228
# 1   NaN   NaN   NaN   NaN   NaN  ...  0.426355  12.752287  5.600745  2.724543
# 2   NaN   NaN   NaN   NaN   NaN  ...  3.471981   8.542147  4.954590  4.822626
# 3   NaN   NaN   NaN   NaN   NaN  ...  2.545323   1.417524  1.001989  1.774487
# 4   NaN   NaN   NaN   NaN   NaN  ... -4.646543  -1.615218  0.351645  2.277683
#
# ...

# %%
# import Metadata csv file.

# %%
Metadata = pd.read_csv('/Users/mijia/Desktop/Spring 2020/BANA 8090/API_NY/Metadata_Country.csv')

# %%
# check number of columns and rows in Metadata DataFrame.

# %%
Metadata.shape
# Out:
# (263, 6)

# %%
# glimpse view of Metadata DataFrame.

# %%
Metadata.head()
# Out:
#   Country Code                     Region          IncomeGroup SpecialNotes  \
# 0          ABW  Latin America & Caribbean          High income          NaN
# 1          AFG                 South Asia           Low income          NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income          NaN
# 3          ALB      Europe & Central Asia  Upper middle income          NaN
# 4          AND      Europe & Central Asia          High income          NaN
#
#      TableName  Unnamed: 5
# 0        Aruba         NaN
# 1  Afghanistan         NaN
# 2       Angola         NaN
# 3      Albania         NaN
# 4      Andorra         NaN

# %%
# count number of NaN in each column for API DataFrame.

# %%
count_NaN_API=API.isnull().sum(axis = 0)

# %%
list(count_NaN_API)
# Out:
# [0,
#  0,
#  0,
#  0,
#  264,
#  140,
#  138,
#  138,
#  138,
#  138,
#  130,
#  126,
#  125,
#  121,
#  121,
#  107,
#  107,
#  107,
#  107,
#  105,
#  101,
#  100,
#  95,
#  95,
#  94,
#  83,
#  78,
#  75,
#  75,
#  72,
#  71,
#  66,
#  63,
#  60,
#  57,
#  46,
#  45,
#  42,
#  40,
#  37,
#  31,
#  31,
#  28,
#  26,
#  25,
#  20,
#  19,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  24,
#  264,
#  264]

# %%
count_NaN_API.loc[count_NaN_API==264]
# Out:
# 1960           264
# 2019           264
# Unnamed: 64    264
# dtype: int64

# %%
# count number of NaN in each column for Metadata DataFrame.

# %%
count_NaN_Metadata=Metadata.isnull().sum(axis = 0)

# %%
count_NaN_Metadata
# Out:
# Country Code      0
# Region           46
# IncomeGroup      46
# SpecialNotes    170
# TableName         0
# Unnamed: 5      263
# dtype: int64

# %%
# Drop all NaN columns in both API and Metadata DataFrames.

# %%
API = API.drop(['1960','2019','Unnamed: 64'], 1)

# %%
Metadata = Metadata.drop(['Unnamed: 5'], 1)

# %%
# change columns names

# %%
API.head()
# Out:
#   Country_Name Country_Code         Indicator_Name     Indicator_Code  1961  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1962  1963  1964  1965  1966  ...       2009       2010      2011  \
# 0   NaN   NaN   NaN   NaN   NaN  ... -10.519748  -3.685030  3.446055
# 1   NaN   NaN   NaN   NaN   NaN  ...  21.390528  14.362441  0.426355
# 2   NaN   NaN   NaN   NaN   NaN  ...   0.858713   4.859220  3.471981
# 3   NaN   NaN   NaN   NaN   NaN  ...   3.350067   3.706891  2.545323
# 4   NaN   NaN   NaN   NaN   NaN  ...  -3.690654  -5.358826 -4.646543
#
#         2012      2013      2014      2015      2016      2017      2018
# ...

# %%
API = API.rename(columns={'Country Name': 'Country_Name', 'Country Code': 'Country_Code', 
                    'Indicator Name': 'Indicator_Name','Indicator Code': 'Indicator_Code'})

# %%
Metadata.head()
# Out:
#   Country Code                     Region          IncomeGroup SpecialNotes  \
# 0          ABW  Latin America & Caribbean          High income          NaN
# 1          AFG                 South Asia           Low income          NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income          NaN
# 3          ALB      Europe & Central Asia  Upper middle income          NaN
# 4          AND      Europe & Central Asia          High income          NaN
#
#      TableName
# 0        Aruba
# 1  Afghanistan
# 2       Angola
# 3      Albania
# 4      Andorra

# %%
# Since the Country_Name in API is the same value of TableName in Metadata, I changed TableName to Country_Name.

# %%
Metadata = Metadata.rename(columns={'Country Code': 'Country_Code', 'IncomeGroup':'Income_Group',
                    'SpecialNotes': 'Special_Notes','TableName': 'Country_Name'})

# %%
# Analyze each columns

# %%
API.head()
# Out:
#   Country_Name Country_Code         Indicator_Name     Indicator_Code  1961  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1962  1963  1964  1965  1966  ...       2009       2010      2011  \
# 0   NaN   NaN   NaN   NaN   NaN  ... -10.519748  -3.685030  3.446055
# 1   NaN   NaN   NaN   NaN   NaN  ...  21.390528  14.362441  0.426355
# 2   NaN   NaN   NaN   NaN   NaN  ...   0.858713   4.859220  3.471981
# 3   NaN   NaN   NaN   NaN   NaN  ...   3.350067   3.706891  2.545323
# 4   NaN   NaN   NaN   NaN   NaN  ...  -3.690654  -5.358826 -4.646543
#
#         2012      2013      2014      2015      2016      2017      2018
# ...

# %%
Metadata.head()
# Out:
#   Country_Code                     Region         Income_Group Special_Notes  \
# 0          ABW  Latin America & Caribbean          High income           NaN
# 1          AFG                 South Asia           Low income           NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income           NaN
# 3          ALB      Europe & Central Asia  Upper middle income           NaN
# 4          AND      Europe & Central Asia          High income           NaN
#
#   Country_Name
# 0        Aruba
# 1  Afghanistan
# 2       Angola
# 3      Albania
# 4      Andorra

# %%
Metadata.Region.unique()
# Out:
# array(['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
#        'Europe & Central Asia', nan, 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
Metadata.Income_Group.unique()
# Out:
# array(['High income', 'Low income', 'Lower middle income',
#        'Upper middle income', nan], dtype=object)

# %%
Metadata.isnull().sum(axis = 1)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 258    1
# 259    1
# 260    0
# 261    0
# 262    1
# Length: 263, dtype: int64

# %%
count_NaN_Metadata

# %%
# Since there are 264 rows in API and 263 rows in Metadata, I'd like to check Country name for each DataFrame.

# %%
Metadata['Code_from_API']=API['Country_Code']

# %%
Metadata.loc[Metadata['Code_from_API']!=Metadata['Country_Code']]
# Out:
#     Country_Code                      Region         Income_Group  \
# 108          IRL       Europe & Central Asia          High income
# 109          IRN  Middle East & North Africa  Upper middle income
# 110          IRQ  Middle East & North Africa  Upper middle income
# 111          ISL       Europe & Central Asia          High income
# 112          ISR  Middle East & North Africa          High income
# ..           ...                         ...                  ...
# 258          XKX       Europe & Central Asia  Upper middle income
# 259          YEM  Middle East & North Africa           Low income
# 260          ZAF          Sub-Saharan Africa  Upper middle income
# 261          ZMB          Sub-Saharan Africa  Lower middle income
# 262          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                          Special_Notes        Country_Name  \
# 108  A simple multiplier is used to convert the nat...             Ireland
# ...

# %%
API.loc[108,]
# Out:
# Country_Name             Not classified
# Country_Code                        INX
# Indicator_Name    GDP growth (annual %)
# Indicator_Code        NY.GDP.MKTP.KD.ZG
# 1961                                NaN
#                           ...
# 2014                                NaN
# 2015                                NaN
# 2016                                NaN
# 2017                                NaN
# 2018                                NaN
# Name: 108, Length: 62, dtype: object

# %%
# After checking the 108th row, I deleted this row.

# %%
API.drop(API.index[108])
# Out:
#      Country_Name Country_Code         Indicator_Name     Indicator_Code  \
# 0           Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1     Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 2          Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3         Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4         Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ..            ...          ...                    ...                ...
# 259        Kosovo          XKX  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 260   Yemen, Rep.          YEM  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 261  South Africa          ZAF  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 262        Zambia          ZMB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 263      Zimbabwe          ZWE  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#          1961      1962      1963       1964       1965      1966  ...  \
# ...
